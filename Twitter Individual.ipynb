# %%
import json
import tweepy as tw
import config_twitter
import pandas

# %%
# establish Twitter API connection
auth = tw.OAuthHandler(config_twitter.consumer_key, config_twitter.consumer_secret)
auth.set_access_token(config_twitter.access_token, config_twitter.access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
# returns False if credentials could not be verified, otherwise a user-object
# https://docs.tweepy.org/en/stable/api.html#API.verify_credentials
user = api.verify_credentials()
user
# Out:
# User(_api=<tweepy.api.API object at 0x000002E760B3F3D0>, _json={'id': 2253262950, 'id_str': '2253262950', 'name': 'Sonish Raj', 'screen_name': 'soni_sonish', 'location': 'Bangalore', 'description': 'B€L!V€ !N yoU', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 30, 'friends_count': 31, 'listed_count': 0, 'created_at': 'Thu Dec 19 09:30:47 +0000 2013', 'favourites_count': 202, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 40, 'lang': None, 'status': {'created_at': 'Thu Apr 29 11:21:02 +0000 2021', 'id': 1387728626775314432, 'id_str': '1387728626775314432', 'text': 'RT @Actor_Siddharth: My phone number was leaked by members of TN BJP and @BJPtnITcell \nOver 500 calls of abuse, rape and death threats to m…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Actor_Siddharth', 'name': 'Siddharth', 'id': 53414786, 'id_str': '53414786', 'indices': [3, 19]}, {'screen_name': 'BJPtnITcell', 'name': 'BJP IT Cell (TN)', 'id': 497828809, 'id_str': '497828809', 'indices': [73, 85]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Apr 29 06:22:32 +0000 2021', 'id': 1387653507814072325, 'id_str': '1387653507814072325', 'text': 'My phone number was leaked by members of TN BJP and @BJPtnITcell \nOver 500 calls of abuse, rape and death threats t… https://t.co/qBU3yCtcRZ', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'BJPtnITcell', 'name': 'BJP IT Cell (TN)', 'id': 497828809, 'id_str': '497828809', 'indices': [52, 64]}], 'urls': [{'url': 'https://t.co/qBU3yCtcRZ', 'expanded_url': 'https://twitter.com/i/web/status/1387653507814072325', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 41361, 'favorite_count': 122634, 'favorited': False, 'retweeted': True, 'lang': 'en'}, 'is_quote_status': False, 'retweet_count': 41361, 'favorite_count': 0, 'favorited': False, 'retweeted': True, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1249166625741234176/BswWUEVe_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1249166625741234176/BswWUEVe_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2253262950/1472450904', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': [], 'suspended': False, 'needs_phone_verification': False}, id=2253262950, id_str='2253262950', name='Sonish Raj', screen_name='soni_sonish', location='Bangalore', description='B€L!V€ !N yoU', url=None, entities={'description': {'urls': []}}, protected=Fa ...

# %%
def connect_api_client():
    auth = tw.OAuthHandler(config_twitter.consumer_key, config_twitter.consumer_secret)
    auth.set_access_token(config_twitter.access_token, config_twitter.access_token_secret)
    # https://docs.tweepy.org/en/stable/getting_started.html#api
    api = tw.API(auth, wait_on_rate_limit=True)
    try:
        # returns False if credentials could not be verified
        # https://docs.tweepy.org/en/stable/api.html#API.verify_credentials
        api.verify_credentials()
        user = api.verify_credentials()
        if not user:
            raise("Credentials could not be verified: Please check config.py")
        print(f"Connected to Twitter API as {user.name}")
    except Exception as e:
        raise e
    return api

# %%
api = connect_api_client()
# Out:
# Connected to Twitter API as Sonish Raj

# %%
# construct a search query
query = 'Smartphones OR Mobiles" -filter:retweets'

# %%
# decide how many tweets to query
###TODO increase this value later to collect a good dataset (try 2000 for instance)
ntweets = 200

# %%
# search and collect relevant tweets
# https://docs.tweepy.org/en/stable/cursor_tutorial.html
# https://docs.tweepy.org/en/stable/code_snippet.html
tweets = [tweet._json for tweet in tw.Cursor(api.search, q=query, lang="en", tweet_mode='extended').items(ntweets)]
len(tweets)
# Out:
# 200

# %%
# example tweet content (json structure)
tweets[0]
# Out:
# {'created_at': 'Thu Jul 29 17:41:18 +0000 2021',
#  'id': 1420801622846943233,
#  'id_str': '1420801622846943233',
#  'full_text': '@Independent Don’t forget most conservatives don’t believe in science, they take to the internet on their smartphones to tell us about it daily',
#  'truncated': False,
#  'display_text_range': [13, 143],
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'Independent',
#     'name': 'The Independent',
#     'id': 16973333,
#     'id_str': '16973333',
#     'indices': [0, 12]}],
#   'urls': []},
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#  'in_reply_to_status_id': 1420800894799646722,
#  'in_reply_to_status_id_str': '1420800894799646722',
#  'in_reply_to_user_id': 16973333,
#  'in_reply_to_user_id_str': '16973333',
#  'in_reply_to_screen_name': 'Independent',
#  'user': {'id': 810681638,
#   'id_str': '810681638',
#   'name': 'Kaylee Brown',
#   'screen_name': 'wozbot1982',
#   'location': 'LV426',
#   'description': 'Space nerd, visionary, font of historical truth, destroyer of ignorance, hound of deceivers, lover of beauty 🌈🏳️\u200d🌈🏳️\u200d⚧️🌙✨',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 727,
#   'friends_count': 871,
#   'listed_count': 6,
#   'created_at': 'Sat Sep 08 10:49:51 +0000 2012',
#   'favourites_count': 45812,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 22474,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1403018338826080259/ftsMpjAo_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1403018338826080259/ftsMpjAo_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/810681638/1614196127',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %%
# save tweets data to json file
file_out = f"raw_tweet_data_{ntweets}.json"
with open(file_out, mode='w') as f:
    f.write(json.dumps(tweets, indent=2))

# %%
# Twitter data analysis task starter.
import html
import json
import string
import re
from nltk import word_tokenize
from nltk.corpus import stopwords
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import matplotlib.pyplot as plt

# %%
# First collect the data in json-file; specify file name here (adjust the number as queried)
fjson = 'raw_tweet_data_200.json'

# %%
# read json file with tweets data
# https://docs.python.org/3/tutorial/inputoutput.html#reading-and-writing-files
with open(fjson) as file:
    data = json.load(file)
len(data)
# Out:
# 200

# %%
# tweet data record example: as documented for the Twitter API
# https://developer.twitter.com/en/docs/twitter-api/v1/data-dictionary/object-model/tweet
data[0]
# Out:
# {'created_at': 'Thu Jul 29 17:41:18 +0000 2021',
#  'id': 1420801622846943233,
#  'id_str': '1420801622846943233',
#  'full_text': '@Independent Don’t forget most conservatives don’t believe in science, they take to the internet on their smartphones to tell us about it daily',
#  'truncated': False,
#  'display_text_range': [13, 143],
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'Independent',
#     'name': 'The Independent',
#     'id': 16973333,
#     'id_str': '16973333',
#     'indices': [0, 12]}],
#   'urls': []},
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#  'in_reply_to_status_id': 1420800894799646722,
#  'in_reply_to_status_id_str': '1420800894799646722',
#  'in_reply_to_user_id': 16973333,
#  'in_reply_to_user_id_str': '16973333',
#  'in_reply_to_screen_name': 'Independent',
#  'user': {'id': 810681638,
#   'id_str': '810681638',
#   'name': 'Kaylee Brown',
#   'screen_name': 'wozbot1982',
#   'location': 'LV426',
#   'description': 'Space nerd, visionary, font of historical truth, destroyer of ignorance, hound of deceivers, lover of beauty 🌈🏳️\u200d🌈🏳️\u200d⚧️🌙✨',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 727,
#   'friends_count': 871,
#   'listed_count': 6,
#   'created_at': 'Sat Sep 08 10:49:51 +0000 2012',
#   'favourites_count': 45812,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 22474,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1403018338826080259/ftsMpjAo_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1403018338826080259/ftsMpjAo_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/810681638/1614196127',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %%
# create pandas dataframe from tweet text content
# https://stackoverflow.com/a/43175477
df_tweets = pd.DataFrame([t['full_text'] for t in data], columns=['text'])
df_tweets
# Out:
#                                                   text
# 0    @Independent Don’t forget most conservatives d...
# 1    For more visit, https://t.co/BRnGyzsBfE Public...
# 2    Smartphone companies are increasing the megapi...
# 3    the amazon alexa app just released a widget fo...
# 4    Huawei launches new smartphones without 5G as ...
# ..                                                 ...
# 195  "We Don't Need Another Hero" by Tina Turner - ...
# 196  "CR1 - SungYourRadio(1)" by CrossRadio1 - Stat...
# 197  @nogreatgame @Huk06 I don't understand cpec li...
# 198  New Android Malware Records Smartphones via VN...
# 199  My mobiles battery down to 36 as a tribute to ...
#
# [200 rows x 1 columns]

# %%
# add selected columns from tweet data fields
df_tweets['retweets'] = [t['retweet_count'] for t in data]
df_tweets['favorites'] = [t['favorite_count'] for t in data]
df_tweets['user'] = [t['user']['screen_name'] for t in data]
df_tweets
# Out:
#                                                   text  retweets  favorites  \
# 0    @Independent Don’t forget most conservatives d...         0          0
# 1    For more visit, https://t.co/BRnGyzsBfE Public...         0          0
# 2    Smartphone companies are increasing the megapi...         0          0
# 3    the amazon alexa app just released a widget fo...         0          0
# 4    Huawei launches new smartphones without 5G as ...         0          0
# ..                                                 ...       ...        ...
# 195  "We Don't Need Another Hero" by Tina Turner - ...         0          0
# 196  "CR1 - SungYourRadio(1)" by CrossRadio1 - Stat...         0          0
# 197  @nogreatgame @Huk06 I don't understand cpec li...         0          0
# 198  New Android Malware Records Smartphones via VN...         0          0
# 199  My mobiles battery down to 36 as a tribute to ...         0         20
#
#                user
# 0        wozbot1982
# 1        EduguruWeb
# 2        Musheer360
# 3    itstheannmarie
# 4     jollymampilly
# ..              ...
# 195     CrossRadio1
# 196     CrossRadio1
# 197          haris6
# 198     vanuatutech
# 199  MianAhtasham15
#
# [200 rows x 4 columns]

# %%
# text cleaning function: see prior class modules
stop_words = set(stopwords.words('english'))

# strictly speaking, this is a closure: uses a wider-scope variable stop_words
# (disregard this note if you are a Python beginner)
def text_cleanup(s):
    s_unesc = html.unescape(re.sub(r"http\S+", "", re.sub('\n+', ' ', s)))
    s_noemoji = s_unesc.encode('ascii', 'ignore').decode('ascii')
    # normalize to lowercase and tokenize
    wt = word_tokenize(s_noemoji.lower())
    
    # filter word-tokens
    wt_filt = [w for w in wt if (w not in stop_words) and (w not in string.punctuation) and (w.isalnum())]
    
    # return clean string
    return ' '.join(wt_filt)

# %%
# add clean text column
# NOTE: apply in pandas applies a function to each element of the selected column
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html
df_tweets['text_clean'] = df_tweets['text'].apply(text_cleanup)
df_tweets
# Out:
#                                                   text  retweets  favorites  \
# 0    @Independent Don’t forget most conservatives d...         0          0
# 1    For more visit, https://t.co/BRnGyzsBfE Public...         0          0
# 2    Smartphone companies are increasing the megapi...         0          0
# 3    the amazon alexa app just released a widget fo...         0          0
# 4    Huawei launches new smartphones without 5G as ...         0          0
# ..                                                 ...       ...        ...
# 195  "We Don't Need Another Hero" by Tina Turner - ...         0          0
# 196  "CR1 - SungYourRadio(1)" by CrossRadio1 - Stat...         0          0
# 197  @nogreatgame @Huk06 I don't understand cpec li...         0          0
# 198  New Android Malware Records Smartphones via VN...         0          0
# 199  My mobiles battery down to 36 as a tribute to ...         0         20
#
#                user                                         text_clean
# 0        wozbot1982  independent dont forget conservatives dont bel...
# 1        EduguruWeb  visit public invited act virtual rangers help ...
# 2        Musheer360  smartphone companies increasing megapixel coun...
# 3    itstheannmarie  amazon alexa app released widget ios renaissan...
# 4     jollymampilly  huawei launches new smartphones without 5g san...
# ..              ...                                                ...
# 195     CrossRadio1  need another hero tina turner platinum collect...
# 196     CrossRadio1  cr1 sungyourradio 1 crossradio1 station id rad...
# 197          haris6  nogreatgame huk06 understand cpec link mobiles...
# 198     vanuatutech  new android malware records smartphones via vn...
# 199  MianAhtasham15  mobiles battery 36 tribute bcci 36 test match ...
#
# [200 rows x 5 columns]

# %%
# sentiment analysis
def sentim_polarity(s):
    return TextBlob(s).sentiment.polarity

def sentim_subject(s):
    return TextBlob(s).sentiment.subjectivity

df_tweets['polarity'] = df_tweets['text_clean'].apply(sentim_polarity)
df_tweets['subjectivity'] = df_tweets['text_clean'].apply(sentim_subject)
df_tweets
# Out:
#                                                   text  retweets  favorites  \
# 0    @Independent Don’t forget most conservatives d...         0          0
# 1    For more visit, https://t.co/BRnGyzsBfE Public...         0          0
# 2    Smartphone companies are increasing the megapi...         0          0
# 3    the amazon alexa app just released a widget fo...         0          0
# 4    Huawei launches new smartphones without 5G as ...         0          0
# ..                                                 ...       ...        ...
# 195  "We Don't Need Another Hero" by Tina Turner - ...         0          0
# 196  "CR1 - SungYourRadio(1)" by CrossRadio1 - Stat...         0          0
# 197  @nogreatgame @Huk06 I don't understand cpec li...         0          0
# 198  New Android Malware Records Smartphones via VN...         0          0
# 199  My mobiles battery down to 36 as a tribute to ...         0         20
#
#                user                                         text_clean  \
# 0        wozbot1982  independent dont forget conservatives dont bel...
# 1        EduguruWeb  visit public invited act virtual rangers help ...
# 2        Musheer360  smartphone companies increasing megapixel coun...
# 3    itstheannmarie  amazon alexa app released widget ios renaissan...
# 4     jollymampilly  huawei launches new smartphones without 5g san...
# ..              ...                                                ...
# 195     CrossRadio1  need another hero tina turner platinum collect...
# 196     CrossRadio1  cr1 sungyourradio 1 crossradio1 station id rad...
# 197          haris6  nogreatgame huk06 understand cpec link mobiles...
# 198     vanuatutech  new android malware records smartphones via vn...
# 199  MianAhtasham15  mobiles battery 36 tribute bcci 36 test match ...
#
#      polarity  subjectivity
# 0    0.000000      0.062500
# 1    0.000000      0.066667
# 2    0.000000      0.500000
# 3    0.000000      0.000000
# 4    0.136364      0.454545
# ..        ...           ...
# 195  0.000000      0.000000
# 196  0.000000      0.000000
# 197  0.000000      0.000000
# 198  0.136364      0.454545
# 199  0.650000      0.600000
#
# [200 rows x 7 columns]

# %%
# define the list of brands to analyze, consistent with the search topic
#  for which the tweets were collected
brands = ['apple', 'samsung','oppo','realme']

# %%
# start a brand comparison dataframe
df_brands = pd.DataFrame(brands, columns=['brand'])
df_brands
# Out:
#      brand
# 0    apple
# 1  samsung
# 2     oppo
# 3   realme

# %%
# example: tweet subset mentioning a given brand
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.contains.html
df_tweets[df_tweets['text_clean'].str.contains("apple")]
# Out:
#                                                   text  retweets  favorites  \
# 16   @ZirJaeger @pips300 @SamsungMobileUS Good luck...         0          0
# 27   Choosing Android means our data are heavily mo...         3          2
# 45   Lossless Audio and Dolby Atmos from Apple Musi...         0          0
# 51   #Android Apple iPhone 5s Review! – SMARTPHONES...         0          0
# 102  Phones considered most safe got unsafe. Quick ...         0          0
#
#                 user                                         text_clean  \
# 16   iPhone13ProMax_  zirjaeger pips300 samsungmobileus good luck al...
# 27     ProjectReboot  choosing android means data heavily monitored ...
# 45          aerezona  lossless audio dolby atmos apple music comes a...
# 51          kamzou08  android apple iphone 5s review smartphones hot...
# 102    Abhi_Banarasi  phones considered safe got unsafe quick update...
#
#      polarity  subjectivity
# 16   0.155556      0.716667
# 27  -0.045833      0.450000
# 45   0.000000      0.000000
# 51   0.250000      0.850000
# 102  0.416667      0.500000

# %%
# function to compute average sentiment of tweets mentioning a given brand
def brand_sentiment(b):
    return df_tweets[df_tweets['text_clean'].str.contains(b)]['polarity'].mean()

# %%
# brand sentiment comparison
df_brands['average_sentiment'] = df_brands['brand'].apply(brand_sentiment)
df_brands
# Out:
#      brand  average_sentiment
# 0    apple           0.155278
# 1  samsung           0.072924
# 2     oppo           0.933333
# 3   realme           0.238194

# %%
# highest sentiment tweets
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html
df_tweets.sort_values(by='polarity', ascending=False).head(20)
# Out:
#                                                   text  retweets  favorites  \
# 136  @satyanadella @satyanadella @BillGates @BradSm...         0          0
# 92   @BradSmi @satyanadella @BillGates @BradSmi @Pa...         0          0
# 170  These Android #smartphones are among the best ...         0          0
# 137  @satyanadella @Bucks @satyanadella @BillGates ...         0          0
# 138  @judsonalthoff @satyanadella @Microsoft @satya...         0          0
# 133  @satyanadella @satyanadella @BillGates @BradSm...         0          0
# 147  @satyanadella @satyanadella @BillGates @BradSm...         0          0
# 40   Did you know ... the tradition of hand-carving...         0          1
# 91   @BradSmi @satyanadella @BillGates @BradSmi @Pa...         0          0
# 135  @satyanadella @satyanadella @BillGates @BradSm...         0          0
# 94   @BradSmi @satyanadella @BillGates @BradSmi @Pa...         0          0
# 95   @BradSmi @satyanadella @coalition_dream @satya...         0          0
# 146  Sell/buy/repair Oppo smartphones best price @ ...         0          0
# 132  @satyanadella @satyanadella @BillGates @BradSm...         0          0
# 145  @jeffteper @satyanadella @satyanadella @BillGa...         0          0
# 143  Rent/sell/buy smartphones tablets best price @...         0          0
# 141  @satyanadella @satyanadella @BillGates @BradSm...         0          0
# 109  @ShambuKushal @TechWiser Those videos are just...         0          1
# 163  You can point at sky, click on the camera Ui a...         0          6
# 11   "The Great Forever" by Janet Jackson - Unbreak...         0          0
#
#                 user                                         text_clean  \
# 136     Sree41202857  satyanadella satyanadella billgates bradsmi pa...
# 92      Sree41202857  bradsmi satyanadella billgates bradsmi padmasr...
# 170      keolacooper      android smartphones among best best smarttech
# 137     Sree41202857  satyanadella bucks satyanadella billgates brad...
# 138     Sree41202857  judsonalthoff satyanadella microsoft satyanade...
# 133     Sree41202857  satyanadella satyanadella billgates bradsmi pa...
# 147     Sree41202857  satyanadella satyanadella billgates bradsmi pa...
# 40          Pier70sf  know tradition wood stone part kneass boat bui...
# 91      Sree41202857  bradsmi satyanadella billgates bradsmi padmasr...
# 135     Sree41202857  satyanadella satyanadella billgates bradsmi pa...
# 94      Sree41202857  bradsmi satyanadella billgates bradsmi padmasr...
# 95      Sree41202857  bradsmi satyanadella satyanadella billgates br...
# 146        sgmobmart  oppo smartphones best price sgmobmart sgbuybac...
# 132     Sree41202857  satyanadella satyanadella billgates bradsmi pa...
# 145     Sree41202857  jeffteper satyanadella satyanadella billgates ...
# 143        sgmobmart  smartphones tablets best price sgmobmart sgbuy...
# 141     Sree41202857  satyanadella satyanadella billgates bradsmi pa...
# 109  a_fresh_shinobi  shambukushal techwiser videos get clicks nothi...
# 163     ShambuKushal  point sky click camera ui get away great image...
# 11       CrossRadio1  great forever janet jackson unbreakable radio ...
#
#      polarity  subjectivity
# 136       1.0          1.00
# 92        1.0          1.00
# 170       1.0          0.30
# 137       1.0          1.00
# 138       1.0          1.00
# 133       1.0          1.00
# 147       1.0          1.00
# 40        1.0          1.00
# 91        1.0          1.00
# 135       1.0          1.00
# 94        1.0          1.00
# 95        1.0          1.00
# 146       1.0          0.30
# 132       1.0          1.00
# 145       1.0          1.00
# 143       1.0          0.30
# 141       1.0          1.00
# 109       0.8          0.70
# 163       0.8          0.75
# 11        0.8          0.75

# %%
# lowest sentiment tweets
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html
df_tweets.sort_values(by='polarity', ascending=True).head(20)
# Out:
#                                                   text  retweets  favorites  \
# 112  This obsession with cameras is making smartpho...         0          2
# 47   In the age of smartphones and CCTVs, it should...         0          3
# 165  "Can't Go Wrong 2" by CrossRadio1 - !\nhttps:/...         0          0
# 122  @Alfredont_ @KoopaTroopa4494 @NintendoAmerica ...         0          0
# 20   Lots of bad things I can say about Twitter, sm...         0          7
# 105  Goddam useless smartphones: can download endle...         2         12
# 190  @Natalie_Pike_ Think it’s the future and that ...         0          1
# 33   @lisefrac @DoorDash @DoordashHelp Ack. I usual...         0          0
# 103  @doggydoorman The govt already knows where eve...         0          1
# 172  Have smartphones made our mental health worse?...         0          1
# 53   What have we let happen  to our #children? We'...         0          0
# 48   @Telegraph All those illegal immigrants busily...         0          0
# 101  Al over the world overseas are treated like VI...         2          2
# 129  Check out \n\nTukzer Tablet Stand, Fully Folda...         0          1
# 178  @saranshjain369 Black Shark mobiles will not l...         0          1
# 194  Over the past decade, we have been increasingl...         1          0
# 96   @MrZackMorris @AriciaAnn zack don't get upset,...         0          0
# 67   Eight-Minute Civil War\nEuros meet wargames in...         0          1
# 169  @youtube    shorts is  waste of the app waste ...         1          0
# 43   @Shannaluscious No way.  When the phone gets s...         0          0
#
#                 user                                         text_clean  \
# 112       Memphis265          obsession cameras making smartphones ugly
# 47   pindropviolence  age smartphones cctvs difficult support argume...
# 165      CrossRadio1  ca go wrong 2 crossradio1 radio smartphones ke...
# 122        Nova2127u  koopatroopa4494 nintendoamerica smartphones no...
# 20    rmccarthyjames  lots bad things say twitter smartphones intern...
# 105    JimmyLevendia  goddam useless smartphones download endless gi...
# 190     RayZinderbar  think future could phased taken account people...
# 33           mr_teem  lisefrac doordash doordashhelp ack usually twi...
# 103       ddnewlin63  doggydoorman govt already knows everyone smart...
# 172       DanORegan3  smartphones made mental health worse please re...
# 53     musingmoments  let happen children let become unfit overweigh...
# 48       neildrewitt  telegraph illegal immigrants busily checking s...
# 101     bakhtkhan711  al world overseas treated like vips humiliated...
# 129       VISWAS2ALL  check tukzer tablet stand fully foldable angle...
# 178  XiaomiIndiaFan2    saranshjain369 black shark mobiles launch india
# 194  DrBruceAJohnson  past decade increasingly concerned potential u...
# 96     MisterShahidi  mrzackmorris ariciaann zack get upset battery ...
# 67     NewBoardGames  civil war euros meet wargames unusual game cze...
# 169  PoliticianLawdr  youtube shorts waste app waste bandwith smartp...
# 43   SoulSoldSeprtly  shannaluscious way phone gets stuck quite pain...
#
#      polarity  subjectivity
# 112 -0.700000      1.000000
# 47  -0.500000      1.000000
# 165 -0.500000      0.900000
# 122 -0.400000      0.400000
# 20  -0.325000      0.583333
# 105 -0.322917      0.576786
# 190 -0.277778      0.486111
# 33  -0.250000      0.250000
# 103 -0.250000      0.625000
# 172 -0.250000      0.400000
# 53  -0.233333      0.633333
# 48  -0.200000      0.400000
# 101 -0.171429      0.478571
# 129 -0.166667      0.433333
# 178 -0.166667      0.433333
# 194 -0.125000      0.625000
# 96  -0.100000      0.520000
# 67  -0.100000      0.700000
# 169 -0.087879      0.166667
# 43  -0.066667      0.633333

# %%
# most retweeted content
df_tweets.sort_values(by='retweets', ascending=False).head(20)
# Out:
#                                                   text  retweets  favorites  \
# 159  #RadheShyam\nCharge Your Mobiles With 100%\nTo...        21         18
# 24   Two specific questions were asked from the Gov...         8         27
# 131  #metaverse is basically the #internet resultin...         4         13
# 27   Choosing Android means our data are heavily mo...         3          2
# 155  Wow. Did not expect this.\n\n“Because of the U...         2          4
# 44   Smartphones with the best battery life that yo...         2          5
# 21   Metro By T-Mobile’s $25 Unlimited Plan Is Live...         2          1
# 187  @AzaadBharatOrg @myogiadityanath @narendramodi...         2          2
# 105  Goddam useless smartphones: can download endle...         2         12
# 101  Al over the world overseas are treated like VI...         2          2
# 18   Motorola Edge 20 Fusion and Motorola Edge 20 L...         1          5
# 183  Huawei launches new smartphones without 5G as ...         1          7
# 124  Huawei launches new smartphones without 5G as ...         1          0
# 60   Huawei's new P50 smartphones feature improved ...         1          2
# 121  Poco X3 GT will not launch in India, company's...         1         10
# 194  Over the past decade, we have been increasingl...         1          0
# 75   Fun fact: there’s only six of these Weiner Mob...         1          6
# 158  At a time of widespread digital insecurity it ...         1          1
# 76   @irenegarth1946 How many have had any kind of ...         1          1
# 49   New Android Malware Records Smartphones via VN...         1          0
#
#                 user                                         text_clean  \
# 159  Srikant00937350  radheshyam charge mobiles 100 tomorrow morning...
# 24      AnumaVidisha  two specific questions asked govt viz whether ...
# 131        chainyoda  metaverse basically internet resulting hyperco...
# 27     ProjectReboot  choosing android means data heavily monitored ...
# 155    sharp_writing  wow expect sanctions new smartphones run 5g wi...
# 44        Gadgets360      smartphones best battery life buy right india
# 21          bestmvno  metro 25 unlimited plan live course theres fin...
# 187        Mokshi146  azaadbharatorg myogiadityanath narendramodi su...
# 105    JimmyLevendia  goddam useless smartphones download endless gi...
# 101     bakhtkhan711  al world overseas treated like vips humiliated...
# 18        Gadgets360  motorola edge 20 fusion motorola edge 20 lite ...
# 183       aparanjape  huawei launches new smartphones without 5g san...
# 124      DUhockeyFan  huawei launches new smartphones without 5g san...
# 60         petapixel  huawei new p50 smartphones feature improved ph...
# 121       Gadgets360  poco x3 gt launch india company india director...
# 194  DrBruceAJohnson  past decade increasingly concerned potential u...
# 75        CChauFOX61  fun fact theres six weiner mobiles world one r...
# 158           fox5ny  time widespread digital insecurity turns oldes...
# 76         eurodderz  irenegarth1946 many kind dialogue historical c...
# 49        igor_os777  new android malware records smartphones via vn...
#
#      polarity  subjectivity
# 159  0.000000      0.000000
# 24   0.100000      0.262500
# 131  0.000000      0.366667
# 27  -0.045833      0.450000
# 155  0.078788      0.484848
# 44   0.642857      0.417857
# 21   0.136364      0.500000
# 187  0.411905      0.461905
# 105 -0.322917      0.576786
# 101 -0.171429      0.478571
# 18   0.000000      0.600000
# 183  0.136364      0.454545
# 124  0.136364      0.454545
# 60   0.101010      0.595960
# 121  0.400000      1.000000
# 194 -0.125000      0.625000
# 75   0.292857      0.367857
# 158  0.000000      0.000000
# 76   0.275000      0.450000
# 49   0.136364      0.454545

# %%
# users producing most retweeted content
df_tweets.sort_values(by='retweets', ascending=False).head(20)['user']
# Out:
# 159    Srikant00937350
# 24        AnumaVidisha
# 131          chainyoda
# 27       ProjectReboot
# 155      sharp_writing
# 44          Gadgets360
# 21            bestmvno
# 187          Mokshi146
# 105      JimmyLevendia
# 101       bakhtkhan711
# 18          Gadgets360
# 183         aparanjape
# 124        DUhockeyFan
# 60           petapixel
# 121         Gadgets360
# 194    DrBruceAJohnson
# 75          CChauFOX61
# 158             fox5ny
# 76           eurodderz
# 49          igor_os777
# Name: user, dtype: object

# %%
# combine all text for a specific brand
def brand_all_text(b):
    # https://stackoverflow.com/a/51871650
    return ' '.join(df_tweets[df_tweets['text_clean'].str.contains(b)]['text_clean'])

# %%
# most common tweet content keywords for a specific brand
# https://amueller.github.io/word_cloud/auto_examples/single_word.html#sphx-glr-auto-examples-single-word-py
# https://amueller.github.io/word_cloud/generated/wordcloud.WordCloud.html#wordcloud.WordCloud
b = 'apple'
wc = WordCloud(width=1200, height=800, max_font_size=110, collocations=False).generate(brand_all_text(b))
plt.axis("off")
plt.imshow(wc, interpolation="bilinear")
plt.show()

# %%
# defined variable f to store all brand names 
f = df_brands['brand']
f
# Out:
# 0      apple
# 1    samsung
# 2       oppo
# 3     realme
# Name: brand, dtype: object

# %%
# most common tweet content keywords for a all brand
i = 0
while i < len(f):
    wc = WordCloud(width=1200, height=800, max_font_size=110, collocations=False).generate(brand_all_text(f[i]))
    plt.axis("off")
    plt.imshow(wc, interpolation="bilinear")
    plt.show()
    i = i + 1
